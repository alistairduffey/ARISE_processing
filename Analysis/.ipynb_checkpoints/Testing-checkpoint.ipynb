# %%
import xarray as xr
import numpy as np

# %%
season = 'all' #'DJF' 
var='tasmax'

data_path = '../Output_data/'
arise = xr.open_dataset(data_path+'ARISE/ARISE_{}_mean.nc'.format(season))
ssp245 = xr.open_dataset(data_path+'SSP245/SSP245_{}_mean.nc'.format(season))
baseline = xr.open_dataset(data_path+'SSP245_baseline/SSP245_baseline_{}_mean.nc'.format(season))
preindustrial = xr.open_dataset(data_path+'preindustrial/preindustrial_{}_mean.nc'.format(season))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/main/lib/python3.10/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     198 try:
# --> 199     file = self._cache[self._key]
#     200 except KeyError:
#
# File ~/.conda/envs/main/lib/python3.10/site-packages/xarray/backends/lru_cache.py:53, in LRUCache.__getitem__(self, key)
#      52 with self._lock:
# ---> 53     value = self._cache[key]
#      54     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/users/a_duffey/GEOL0013/Output_data/ARISE/ARISE_all_mean.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ...

# %%
arise.tasmax
# Out:
# <xarray.DataArray 'tasmax' (y: 144, x: 192)>
# array([[230.58937, 230.60039, 230.60974, ..., 230.58368, 230.58498, 230.58885],
#        [231.58464, 231.49599, 231.4074 , ..., 231.88188, 231.77815, 231.68   ],
#        [232.66797, 232.50981, 232.35838, ..., 233.20901, 233.01913, 232.8374 ],
#        ...,
#        [261.87854, 261.93784, 261.99796, ..., 261.68777, 261.74768, 261.81577],
#        [261.49844, 261.52597, 261.55478, ..., 261.40283, 261.438  , 261.4699 ],
#        [261.0894 , 261.0967 , 261.10025, ..., 261.0715 , 261.07755, 261.08548]],
#       dtype=float32)
# Coordinates:
#   * y        (y) float64 -89.38 -88.12 -86.88 -85.62 ... 85.62 86.88 88.12 89.38
#   * x        (x) float64 0.9375 2.812 4.688 6.562 ... 353.4 355.3 357.2 359.1

# %%
(arise-ssp245)[var].plot()

# %%
(arise-baseline)[var].plot()

# %%
(100*(arise-baseline)/(baseline-preindustrial))[var].plot(levels=np.arange(-100, 100, 20))
